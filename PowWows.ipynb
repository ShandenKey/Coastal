# %%
import requests

# %%
from bs4 import BeautifulSoup as BS

# %%
URL = 'https://www.visitcalifornia.com/experience/pow-wows-california/'

response = requests.get(URL)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="en" class=""><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/><script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript" charSet="UTF-8" data-domain-script="31742eae-8d5d-49c6-ae00-4381f8d8076d"></script><script type="text/javascript">function OptanonWrapper() { window.dataLayer.push( { event: \'OneTrustGroupsUpdated\'} )}</script><title data-gatsby-head="true">Pow Wows in California | Visit California</title><meta name="generator" content="Gatsby 5.11.0"/><meta name="msapplication-TileColor" content="#da532c" data-gatsby-head="true"/><meta name="id" content="458582" data-gatsby-head="true"/><meta property="og:type" content="article" data-gatsby-head="true"/><meta property="og:title" content="Pow Wows in California | Visit California" data-gatsby-head="true"/><meta name="description" content="Learn how to
# ...

# %%
soup = BS(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <script charset="UTF-8" data-domain-script="31742eae-8d5d-49c6-ae00-4381f8d8076d" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper() { window.dataLayer.push( { event: 'OneTrustGroupsUpdated'} )}
#   </script>
#   <title data-gatsby-head="true">
#    Pow Wows in California | Visit California
#   </title>
#   <meta content="Gatsby 5.11.0" name="generator"/>
#   <meta content="#da532c" data-gatsby-head="true" name="msapplication-TileColor"/>
#   <meta content="458582" data-gatsby-head="true" name="id"/>
#   <meta content="article" data-gatsby-head="true" property="og:type"/>
# ...

# %%
soup.find('h4').text
# Out:
# 'The Origins of Pow Wow'

# %%
months = soup.findAll('h4')
print(type(months))
months
# Out:
# <class 'bs4.element.ResultSet'>
# [<h4>The Origins of Pow Wow</h4>,
#  <h4><br/>
#  How to Watch a Pow Wow</h4>,
#  <h4>Pow Wow Etiquette</h4>,
#  <h4>Where to Attend Pow Wows in California</h4>,
#  <h4>January</h4>,
#  <h4>June</h4>,
#  <h4>September</h4>,
#  <h4>October</h4>,
#  <h4>November</h4>,
#  <h4 class="m-cardListIntro__heading">Traveler Photos</h4>,
#  <h4 class="footerMain__inner--heading">About Us</h4>,
#  <h4 class="footerMain__inner--heading">Stay Connected</h4>,
#  <h4 class="footerMain__inner--heading">Proud Partner of</h4>]

# %%
soup.findAll('a').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 soup.findAll('a').text
#
# File ~\anaconda3\Lib\site-packages\bs4\element.py:2428, in ResultSet.__getattr__(self, key)
#    2426 def __getattr__(self, key):
#    2427     """Raise a helpful exception to explain a common code fix."""
# -> 2428     raise AttributeError(
#    2429         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2430     )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
soup.findall('a').text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 soup.findall('a').text
#
# TypeError: 'NoneType' object is not callable
